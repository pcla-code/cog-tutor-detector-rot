# %%
import pandas as pd

# %%
TwoThree = pd.read_csv('2022_2023.csv')
TwoThree = TwoThree[["anon_stu_id", "answer rank","Who am I?","code","valence"]]
TwoThree
# Out:
#          anon_stu_id  answer rank  \
# 0     stu_AGZKP8305N            1
# 1     stu_AGZKP8305N            2
# 2     stu_AGZKP8305N            3
# 3     stu_AGZKP8305N            3
# 4     stu_AGZKP8305N            4
# ...              ...          ...
# 1399  stu_ZMXXH2486L           18
# 1400  stu_ZMXXH2486L           19
# 1401  stu_ZMXXH2486L           19
# 1402  stu_ZMXXH2486L           20
# 1403  stu_ZMXXH2486L           20
#
#                                               Who am I?  code   valence
# 0                                         I am a female   1.0    female
# 1     I am one who can get overwhelmed and stressed ...  45.0  negative
# 2     I am someone who really likes dinosaurs and dr...  26.0  positive
# 3     I am someone who really likes dinosaurs and dr...  24.0  positive
# 4     I am an extrovert, and do not like being alone...  45.0  negative
# ...                                                 ...   ...       ...
# ...

# %%
TwoThree.to_csv("2022_2023_CLEAN.csv", index=False)  # Save as CSV
