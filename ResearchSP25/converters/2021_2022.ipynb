# %%
import pandas as pd
OneTwo = pd.read_csv('2021_2022_School2.csv')
OneTwo = OneTwo[["anon_userid", "Answer Rank","Who Am I?","Code","Valence"]]
OneTwo
# Out:
#         anon_userid  Answer Rank               Who Am I?  Code      Valence
# 0    stu_AJMSL3816R            3                a person  21.0         none
# 1    stu_AJMSL3816R           16                 A hater  44.0     negative
# 2    stu_AJMSL3816R           12  not everyones favriote  46.0     negative
# 3    stu_AJMSL3816R           19                 A niece  12.0      neutral
# 4    stu_AJMSL3816R           19                 A niece   2.0         girl
# ..              ...          ...                     ...   ...          ...
# 609  stu_ZWGAX6637V            4             A zelda fan  29.0      neutral
# 610  stu_ZWGAX6637V            4             A zelda fan  24.0     positive
# 611  stu_ZWGAX6637V           11                  A dude   2.0          boy
# 612  stu_ZWGAX6637V            9                A person  19.0         none
# 613  stu_ZWGAX6637V           12           A Mathia user  22.0  mathia user
#
# [614 rows x 5 columns]

# %%
OneTwo.to_csv("2021_2022_CLEAN.csv", index=False)  # Save as CSV
